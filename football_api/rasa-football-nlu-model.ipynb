# %%
# !apt install rustc && apt install cargo
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libstd-rust-1.75 libstd-rust-dev
# Suggested packages:
#   cargo llvm-17 lld-17 clang-17
# The following NEW packages will be installed:
#   libstd-rust-1.75 libstd-rust-dev rustc
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 91.4 MB of archives.
# After this operation, 369 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstd-rust-1.75 amd64 1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04 [46.3 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstd-rust-dev amd64 1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04 [41.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 rustc amd64 1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04 [3,404 kB]
# Fetched 91.4 MB in 6s (15.4 MB/s)
# ^C

# %%
# !pip install rasa[transformers]==3.6.15
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.5/203.5 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 35.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 27.2 MB/s eta 0:00:00
# ...

# %%
# !pip install nest-asyncio==1.5.6
# !pip install --upgrade ipykernel
# Out:
# ...
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.6.0
#     Uninstalling nest-asyncio-1.6.0:
#       Successfully uninstalled nest-asyncio-1.6.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.29.5 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.52 which is incompatible.
# ...

# %% [markdown]
# ## Preparing Training Data

# %%
train_data = {
    'greet': [
        'hi',
        'hooo',
        'Hello buddy',
        'salut',
        'Hey',
        'Good Morning',
        'Bonsoir',
        'Salut mon ami',
        'Hello there!',
        # 'Greetings!',
        # 'Howdy',
        # 'Hi there',
        # 'Heya',
        # 'Good evening',
        # 'What’s up?',
        # 'Hello friend',
        # 'Yo',
        # 'Hi buddy',
        # 'Bonjour',
        # 'Hiya'
    ],
    'self-introduce': [
        'who are you?',
        'qui es-tu?',
        'how can you help me',
        'comment pouvez vous m\'aider',
        'why would I need you?',
        'Pourquoi aurais-je besoin de toi ?',
        'help please',
        'Aidez-moi, s\'il vous plaît',
        'I cannot understand you',
        # 'Je ne te comprends pas',
        # 'what is your name?',
        # 'quel est ton nom?',
        # 'what can you do?',
        # 'que pouvez-vous faire?',
        # 'how do you work?',
        # 'comment fonctionnez-vous?',
        # # 'I need assistance',
        # 'J\'ai besoin d\'aide',
        # 'can you assist me?',
        # 'pouvez-vous m\'aider?',
        # 'tell me more about yourself',
        # 'parlez-moi plus de vous',
        # 'why are you here?',
        # 'pourquoi es-tu ici?',
        # 'please assist me',
        # 's\'il vous plaît, aidez-moi',
        # 'I don\'t understand',
        # 'je ne comprends pas',
        # 'what is your purpose?',
        # 'quel est ton but?'
    ],
    'departure': [
        'good bye',
        'au revoir',
        'See you later',
        'A plus Tard',
        'stop',
        'arrêt',
        'exit',
        'sortir',
        'farewell',
        'adieu',
        'bye bye',
        # 'à bientôt',
        # 'take care',
        # 'prends soin de toi',
        # 'ciao',
        # 'tchao',
        # 'peace out',
        # 'paix',
        # 'later',
        # 'à plus'
    ],
    'team-next-match': [
        'when will be the match of [liverpool](team_name)',
        'when will [Aston Villa](team_name) play?',
        'quand aura lieu le match de [liverpool](team_name)',
        'quand est-ce que [Aston Villa](team_name) jouera ?',
        '[man city] (team_name) matches',
        'what is the calender of [Arsenal](team_name) matches?',
        'Matchs de [man city] (team_name)',
        'quel est le calendrier des matchs d\'[Arsenal](team_name) ?',
        '[Chelsea](team_name) calender',
        'Will [Manchester United](team_name) play any match soon?',
        'Calendrier [Chelsea](team_name)',
        'Est-ce que [Manchester United](team_name) jouera bientôt un match?',
        # 'when is the next game for [Tottenham](team_name)?',
        # 'schedule of [Everton](team_name) matches',
        # 'what time is the [Leicester City](team_name) game?',
        # 'When does [West Ham](team_name) play next?',
        # 'what are the upcoming matches for [Southampton](team_name)?',
        # 'when is [Leeds United](team_name) playing?',
        # 'match schedule for [Brighton](team_name)',
        # 'next fixtures for [Crystal Palace](team_name)',
        # 'when is the next [Burnley](team_name) match?',
        # 'what is the schedule for [Newcastle United](team_name) matches?'
    ],
    'match-time':[
        '[Liverpool](team_name) vs [Man United](team_name) match time',
        'Heure du match [Liverpool](team_name) contre [Man United](team_name)',
        'When is the match of [Chelsea](team_name)?',
        'Quand a lieu le match de [Chelsea](team_name) ?',
        'Tell me the match time of [Aston Villa](team_name) and [Arsenal](team_name)',
        "Dites-moi l'heure du match de [Aston Villa](team_name) et [Arsenal](team_name)",
        '[Crystal Palace](team_name) vs [Leicester City](team_name)',
        '[Crystal Palace](team_name) contre [Leicester City](team_name)',
        'what is the time of [West Ham](team_name) vs [Norwich City](team_name)?',
        'quelle est l\'heure du match [West Ham](team_name) contre [Norwich City](team_name)?',
        # 'What time does [Tottenham](team_name) play against [Everton](team_name)?',
        # 'Quelle est l\'heure du match [Tottenham](team_name) contre [Everton](team_name) ?',
        # 'At what time is the [Manchester City](team_name) vs [Brighton](team_name) match?',
        # 'À quelle heure est le match [Manchester City](team_name) contre [Brighton](team_name) ?',
        # 'Could you tell me the time of the [Leeds United](team_name) vs [Wolverhampton](team_name) game?',
        # 'Pouvez-vous me dire l\'heure du match [Leeds United](team_name) contre [Wolverhampton](team_name) ?',
        # 'When does the match between [Burnley](team_name) and [Fulham](team_name) start?',
        # 'Quand commence le match entre [Burnley](team_name) et [Fulham](team_name) ?',
        # 'Give me the match schedule for [Southampton](team_name) vs [Newcastle](team_name).',
        # 'Donnez-moi l\'horaire du match [Southampton](team_name) contre [Newcastle](team_name).'
    ],
    'match-result': [
        'result of [Brentford](team_name) match',
        'résultat du match de [Brentford](team_name)',
        'score of [Wolverhampton](team_name) vs [Newcastle](team_name)',
        'score de [Wolverhampton](team_name) contre [Newcastle](team_name)',
        'What happened in [Tottenham](team_name) and [Manchester City](team_name) match?',
        'Que s\'est-il passé lors du match entre [Tottenham](team_name) et [Manchester City](team_name)?',
        '[Bournemouth](team_name) and [Everton](team_name) result',
        'Résultat de [Bournemouth](team_name) et [Everton](team_name)',
        'tell me [Man United](team_name) vs [Newcastle United](team_name) match score',
        'dites-moi le score du match [Man United](team_name) contre [Newcastle United](team_name)',
        # 'What was the final score between [Chelsea](team_name) and [Arsenal](team_name)?',
        # 'Quel a été le score final entre [Chelsea](team_name) et [Arsenal](team_name) ?',
        # 'Show me the result of [Liverpool](team_name) vs [Leicester City](team_name)',
        # 'Montrez-moi le résultat de [Liverpool](team_name) contre [Leicester City](team_name)',
        # 'Did [West Ham](team_name) win against [Aston Villa](team_name)?',
        # '[West Ham](team_name) a-t-il gagné contre [Aston Villa](team_name) ?',
        # 'What\'s the outcome of the match between [Leeds United](team_name) and [Crystal Palace](team_name)?',
        # 'Quel est le résultat du match entre [Leeds United](team_name) et [Crystal Palace](team_name) ?',
        # 'Can you give me the score of [Brighton](team_name) vs [Southampton](team_name)?',
        # 'Peux-tu me donner le score de [Brighton](team_name) contre [Southampton](team_name) ?',
        # 'I want to know the result of [Fulham](team_name) against [Burnley](team_name)',
        # 'Je veux connaître le résultat de [Fulham](team_name) contre [Burnley](team_name)',
        # 'Tell me the final result of [Sheffield United](team_name) vs [Norwich City](team_name)',
        # 'Dites-moi le résultat final de [Sheffield United](team_name) contre [Norwich City](team_name)'
    ]
} # Keys are intents and values are examples

# %%
team_name_lookup = [
    "Liverpool", "LFC",
    "Aston Villa", "AVFC",
    "Manchester City", "Man City",
    "Arsenal", "AFC",
    "Chelsea", "CFC",
    "Manchester United", "Man United",
    "Tottenham Hotspur", "Tottenham",
    "Everton", "EFC",
    "Leicester City", "LCFC",
    "West Ham United", "West Ham",
    "Southampton", "SFC",
    "Leeds United", "LUFC",
    "Brighton & Hove Albion", "Brighton",
    "Crystal Palace", "CPFC",
    "Burnley", "BFC",
    "Newcastle United", "Newcastle",
    "Brentford", "BFC",
    "Wolverhampton Wanderers", "Wolves",
    "Bournemouth", "AFC Bournemouth",
    "Fulham", "FFC",
    "Sheffield United", "SUFC",
    "Norwich City", "NCFC"
]

# %%
# Create yml file for nlu data
nlu_data = []
nlu_data.append('version: "3.1"')
nlu_data.append('nlu:')

for intent_name, examples in train_data.items():
    nlu_data.append(f'- intent: {intent_name}')
    nlu_data.append('  examples: |')
    for example in examples:
        if example.strip() == "": continue
        nlu_data.append(f'    - {example}')

nlu_data.append('- lookup: team_name')
nlu_data.append('  examples: |')

for team_name in team_name_lookup:
    nlu_data.append(f'    - {team_name}')

with open('./data.yml', 'w') as dest:
    dest.write("\n".join(nlu_data))

# %%
# Create a yml file for domain data (only intents)
domain_data = ['version: "3.1"', 'intents:']
for intent_name, examples in train_data.items():
    domain_data.append(f'  - {intent_name}')

with open('./domain.yml', 'w') as dest:
    dest.write("\n".join(domain_data))

# %%
config = """
# The config recipe.
# https://rasa.com/docs/rasa/model-configuration/
recipe: default.v1
language: en
pipeline:
- name: "WhitespaceTokenizer"
- name: LanguageModelFeaturizer
  model_weights: "rasa/LaBSE"
  model_name: "bert"
- name: CountVectorsFeaturizer
  analyzer: char_wb
  min_ngram: 1
  max_ngram: 2
- name: CountVectorsFeaturizer
- name: DIETClassifier
  epochs: 25
  num_transformer_layers: 2
  transformer_size: 64
  use_masked_language_model: True
  drop_rate: 0.2
  weight_sparsity: 0.7
  batch_size: 2
  embedding_dimension: 20
  hidden_layer_sizes:
    text: [128, 64]
""".strip()

with open(f'./config.yml', 'w') as dest:
    dest.write(config)

# %% [markdown]
# ## Train Model

# %%
# !rasa train --data ./data.yml --domain ./domain.yml --config ./config.yml --out /content/models
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/core/tracker_store.py:1044: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# (0lqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B Rasa Open Source reports anonymous usage telemetry to help improve the product (0x(B
# (0x(B for all its users.                                                             (0x(B
# (0x(B                                                                                (0x(B
# ...

# %%
model_cp = '/content/models/nlu-20240702-155032-immature-flight.tar.gz'

# %% [markdown]
# ## Testing Model Inference

# %%
import asyncio
from rasa.core.agent import Agent
import nest_asyncio
# Out:
# 2024-07-02 18:18:59.583105: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-02 18:18:59.646997: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-02 18:18:59.648525: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-02 18:19:02.075744: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
nest_asyncio.apply()
model = Agent.load(model_path=model_cp)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 2024-07-02 18:19:13.770548: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1539542016 exceeds 10% of free system memory.
# 2024-07-02 18:19:24.225626: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1539542016 exceeds 10% of free system memory.
# 2024-07-02 18:19:25.050710: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1539542016 exceeds 10% of free system memory.
# 2024-07-02 18:19:30.987999: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1539542016 exceeds 10% of free system memory.
# ...

# %%
message = 'Liverpool vs Chelsea next match'
pred = asyncio.run(
    model.parse_message(message_data=message)
)
# Out:
# 2024-07-02 18:20:46 [debug    ] processor.message.parse        parse_data_entities=[{'entity': 'team_name', 'start': 0, 'end': 9, 'confidence_entity': 0.9897488951683044, 'value': 'Liverpool', 'extractor': 'DIETClassifier'}, {'entity': 'team_name', 'start': 13, 'end': 20, 'confidence_entity': 0.9608646631240845, 'value': 'Chelsea', 'extractor': 'DIETClassifier'}] parse_data_intent={'name': 'match-time', 'confidence': 0.9970775842666626} parse_data_text=Liverpool vs Chelsea next match
# /usr/local/lib/python3.10/dist-packages/rasa/shared/utils/io.py:99: UserWarning: Parsed an entity 'team_name' which is not defined in the domain. Please make sure all entities are listed in the domain.
#   More info at https://rasa.com/docs/rasa/domain

# %%
pred
# Out:
# {'text': 'Liverpool vs Chelsea next match',
#  'intent': {'name': 'match-time', 'confidence': 0.9970775842666626},
#  'entities': [{'entity': 'team_name',
#    'start': 0,
#    'end': 9,
#    'confidence_entity': 0.9897488951683044,
#    'value': 'Liverpool',
#    'extractor': 'DIETClassifier'},
#   {'entity': 'team_name',
#    'start': 13,
#    'end': 20,
#    'confidence_entity': 0.9608646631240845,
#    'value': 'Chelsea',
#    'extractor': 'DIETClassifier'}],
#  'text_tokens': [(0, 9), (10, 12), (13, 20), (21, 25), (26, 31)],
#  'intent_ranking': [{'name': 'match-time', 'confidence': 0.9970775842666626},
#   {'name': 'team-next-match', 'confidence': 0.002098563127219677},
#   {'name': 'match-result', 'confidence': 0.000680484576150775},
#   {'name': 'departure', 'confidence': 0.00014055670180823654},
#   {'name': 'greet', 'confidence': 2.235999772892683e-06},
#   {'name': 'self-introduce', 'confidence': 5.647790999319113e-07}]}
